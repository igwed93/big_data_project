# %% [markdown]
# <a href="https://colab.research.google.com/github/igwed93/big_data_project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Java (Hadoop's prerequisite)
# !apt-get install openjdk-8-jdk-headless --qq > /dev/null

# Download and Unzip Hadoop
# !wget -q https://archive.apache.org/dist/hadoop/common/hadoop-3.3.0/hadoop-3.3.0.tar.gz
# !tar -xvf hadoop-3.3.0.tar.gz > /dev/null

# 3. Set Environment Variables so Colab knows where Hadoop is
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["HADOOP_HOME"] = "/content/hadoop-3.3.0"
os.environ["PATH"] += os.pathsep + "/content/hadoop-3.3.0/bin"

# 4. Verify it works!
# !hadoop version
# Out:
# E: Command line option --qq is not understood in combination with the other options
# ERROR: JAVA_HOME /usr/lib/jvm/java-8-openjdk-amd64 does not exist.
